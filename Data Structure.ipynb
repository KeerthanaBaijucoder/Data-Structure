# %%
Exercise: List

# %%
# Q1. 
import random
numbers = [random.randint(1, 10) for _ in range(5)]
print("Original list:", numbers)
# Q2.
new_values = [random.randint(1, 10) for _ in range(3)]
numbers.extend(new_values)
print("Updated list:", numbers)
# Q3. 
print("Elements in the list:")
for number in numbers:
    print(number)
# Out:
# Original list: [7, 9, 3, 2, 5]
# Updated list: [7, 9, 3, 2, 5, 4, 8, 7]
# Elements in the list:
# 7
# 9
# 3
# 2
# 5
# 4
# 8
# 7

# %%
Exercise: Dictionary

# %%
# Q1. 
person = {
    'name': 'John',
    'age': 25,
    'address': 'New York'
}
print("Original dictionary:", person)
# Q2. 
person['phone'] = '1234567890'
print("Updated dictionary:", person)
# Out:
# Original dictionary: {'name': 'John', 'age': 25, 'address': 'New York'}
# Updated dictionary: {'name': 'John', 'age': 25, 'address': 'New York', 'phone': '1234567890'}

# %%
Exercise: Set

# %%
# Q1.
numbers = {1, 2, 3, 4, 5}
print("Original set:", numbers)
# Q2. 
numbers.add(6)
print("Set after adding 6:", numbers)
# Q3.
numbers.remove(3)
print("Set after removing 3:", numbers)
# Out:
# Original set: {1, 2, 3, 4, 5}
# Set after adding 6: {1, 2, 3, 4, 5, 6}
# Set after removing 3: {1, 2, 4, 5, 6}

# %%
Exercise: Tuple

# %%
# Q1. 
my_tuple = (1, 2, 3, 4)
print("Tuple:", my_tuple)
# Q2. 
print("Length of the tuple:", len(my_tuple))
# Out:
# Tuple: (1, 2, 3, 4)
# Length of the tuple: 4
